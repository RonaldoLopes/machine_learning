# %% [markdown]
# <a href="https://colab.research.google.com/github/RonaldoLopes/machine_learning/blob/main/algoritmo_binarizacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('estrada.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
suave = cv2.GaussianBlur(img, (7, 7), 0) #aplica blur
(T, bin) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY)
(T, binI) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY_INV)
resultado = np.vstack([np.hstack([suave, bin]), np.hstack([binI, cv2.bitwise_and(img, img, mask = binI)])])
# cv2.imshow("Binarização da imagem", resultado) está desativado no colab devido a problemas de compatibilidade que podem causar falhas nas sessões Jupyte
cv2_imshow(resultado)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=396x296>
# -1

# %%
#exibindo em cores, escala de cinza e binária

# Carregar a imagem original
img = cv2.imread('estrada.jpg')

# Converter para escala de cinza
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Aplicar filtro de suavização
suave = cv2.GaussianBlur(img_gray, (7, 7), 0)

# Binarizar a imagem
(T, bin) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY)
(T, binI) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY_INV)

# Criar imagens colorida, em cinza e binária
img_colorida = img
img_cinza = cv2.cvtColor(img_gray, cv2.COLOR_GRAY2BGR)
img_binaria = cv2.cvtColor(bin, cv2.COLOR_GRAY2BGR)

# Concatenar as imagens horizontalmente
resultado = np.hstack([img_colorida, img_cinza, img_binaria])

# Exibir a imagem resultante
cv2_imshow(resultado)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=594x148>
# -1
